# %%
import pandas as pd

# %%
rawdata=pd.read_csv(r"C:\Users\Aqsa Kanwal\Desktop\raw_data1\diabetes_unclean.csv")
rawdatacopy=rawdata.copy()
print(rawdatacopy.to_string())
# Out:
#        ID  No_Pation Gender   AGE    Urea     Cr  HbA1c   Chol     TG   HDL   LDL  VLDL    BMI CLASS
# 0     502      17975      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 1     735      34221      M  26.0   4.500   62.0   4.90   3.70   1.40  1.10  2.10   0.6  23.00     N
# 2     420      47975      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 3     680      87656      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 4     504      34223      M  33.0   7.100   46.0   4.90   4.90   1.00  0.80  2.00   0.4  21.00     N
# 5     634      34224      F  45.0   2.300   24.0   4.00   2.90   1.00  1.00  1.50   0.4  21.00     N
# 6     721      34225      F  50.0   2.000   50.0   4.00   3.60   1.30  0.90  2.10   0.6  24.00     N
# 7     421      34227      M  48.0   4.700   47.0   4.00   2.90   0.80  0.90  1.60   0.4  24.00     N
# ...

# %%
rawdatacopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %% [markdown]
# # locate

# %%
rawdatacopy.loc[2]
# Out:
# ID             420
# No_Pation    47975
# Gender           F
# AGE           50.0
# Urea           4.7
# Cr            46.0
# HbA1c          4.9
# Chol           4.2
# TG             0.9
# HDL            2.4
# LDL            1.4
# VLDL           0.5
# BMI           24.0
# CLASS            N
# Name: 2, dtype: object

# %%
rawdatacopy.loc[[2,3]]
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
#
#     BMI CLASS
# 2  24.0     N
# 3  24.0     N

# %%
rawdata.loc[[2,3],["Gender","AGE"]]
# Out:
#   Gender   AGE
# 2      M  50.0
# 3      F  50.0

# %% [markdown]
# # slicing

# %%
rawdata[:7]
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      M  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224      F  45.0   2.3  24.0    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225      F  50.0   2.0  50.0    4.0   3.6  1.3  0.9  2.1   0.6
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# 5  21.0     N
# 6  24.0     N

# %%
for x in rawdatacopy.index:
    if rawdatacopy.loc[x,"AGE"] >50:
        rawdatacopy.loc[x]=50

# %%
print(rawdatacopy.to_string())
# Out:
#        ID  No_Pation Gender   AGE    Urea     Cr  HbA1c   Chol     TG   HDL   LDL  VLDL    BMI CLASS
# 0     502      17975      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 2     420      47975      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 3     680      87656      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 4     504      34223      M  33.0   7.100   46.0   4.90   4.90   1.00  0.80  2.00   0.4  21.00     N
# 5     634      34224      F  45.0   2.300   24.0   4.00   2.90   1.00  1.00  1.50   0.4  21.00     N
# 6     721      34225      F  50.0   2.000   50.0   4.00   3.60   1.30  0.90  2.10   0.6  24.00     N
# 7     421      34227      M  48.0   4.700   47.0   4.00   2.90   0.80  0.90  1.60   0.4  24.00     N
# 8     670      34229      M  43.0   2.600   67.0   4.00   3.80   0.90  2.40  3.70   1.0  21.00     N
# ...

# %%
indices_to_drop=[]
for x in rawdatacopy.index:
    if rawdatacopy.loc[x,"AGE"] < 30:
        indices_to_drop.append(x)
rawdatacopy.drop(indices_to_drop,inplace=True)
print(rawdatacopy.to_string())
# Out:
#        ID  No_Pation Gender   AGE    Urea     Cr  HbA1c   Chol     TG   HDL   LDL  VLDL    BMI CLASS
# 0     502      17975      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 2     420      47975      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 3     680      87656      F  50.0   4.700   46.0   4.90   4.20   0.90  2.40  1.40   0.5  24.00     N
# 4     504      34223      M  33.0   7.100   46.0   4.90   4.90   1.00  0.80  2.00   0.4  21.00     N
# 5     634      34224      F  45.0   2.300   24.0   4.00   2.90   1.00  1.00  1.50   0.4  21.00     N
# 6     721      34225      F  50.0   2.000   50.0   4.00   3.60   1.30  0.90  2.10   0.6  24.00     N
# 7     421      34227      M  48.0   4.700   47.0   4.00   2.90   0.80  0.90  1.60   0.4  24.00     N
# 8     670      34229      M  43.0   2.600   67.0   4.00   3.80   0.90  2.40  3.70   1.0  21.00     N
# ...

# %%
rawdatacopy.loc[[2,3],["Gender", "AGE"]]
# Out:
#   Gender   AGE
# 2      F  50.0
# 3      F  50.0

# %%
rawdatacopy.iloc[1,2]
# Out:
# 'F'

# %%
rawdatacopy.loc[2, "Gender" ]="F"
rawdatacopy
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# 5     634      34224      F  45.0   2.3  24.0    4.0   2.9  1.0  1.0  1.5
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  50.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  50.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  50.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  50.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  50.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 2      0.5  24.0     N
# ...
